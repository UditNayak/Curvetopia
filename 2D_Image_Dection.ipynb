# %% [markdown]
# # Detecting the 2D Shape

# %%
# # importing the necessary Library

# import cv2
# import matplotlib.pyplot as plt
# import numpy as np
# from google.colab.patches import cv2_imshow

# #Reading the image

# img = cv2.imread("occlusion1_rec.png")

# #Converting the image to gray scale

# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# # Display the image

# plt.imshow(gray, cmap='gray')
# plt.show()

# %%
# #Adding the THRESSHOLD Values

# _, threshold = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# #Finding the Contours using a findCounter Function

# contours, _ = cv2.findContours(threshold, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# i=0

# #List for storing names of all the shapes

# for contour in contours:
#   if i == 0:
#     i = 1
#     continue

#   #Approximating the shapes
#   approx = cv2.approxPolyDP(contour, 0.01*cv2.arcLength(contour, True), True)

#   #drawContours() function
#   cv2.drawContours(img, [contour], 0, (0, 0, 255), 5)

#   #Finding the center of the shape
#   M = cv2.moments(contour)
#   if M['m00'] != 0.0:
#     x = int(M['m10']/M['m00'])
#     y = int(M['m01']/M['m00'])

#   #putting shape name at the centre of each shape
#   if len(approx) == 3:
#     cv2.putText(img, 'Triangle', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
#   elif len(approx) == 4:
#     cv2.putText(img, 'Quadrilateral', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
#   elif len(approx) == 5:
#     cv2.putText(img, 'Pentagon', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
#   elif len(approx) == 6:
#     cv2.putText(img, 'Hexagon', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
#   else:
#     cv2.putText(img, 'Circle', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

# # Displaying the image using cv2_imshow
# cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-34862d7a17cd> in <cell line: 43>()
#      41
#      42  # Displaying the image using cv2_imshow
# ---> 43 cv2_imshow(img)
#
# NameError: name 'cv2_imshow' is not defined

# %%
# Importing necessary libraries
import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

# Reading the image
img = cv2.imread("occlusion1_rec.png")

# Check if the image was successfully loaded
if img is None:
    print("Error: Image not found or unable to read.")
else:
    # Converting the image to gray scale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Display the grayscale image
    plt.imshow(gray, cmap='gray')
    plt.show()

    # Adding the THRESHOLD values
    _, threshold = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

    # Finding the contours using findContours function
    contours, _ = cv2.findContours(threshold, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    i = 0

    # List for storing names of all the shapes
    for contour in contours:
        if i == 0:
            i = 1
            continue

        # Approximating the shapes
        approx = cv2.approxPolyDP(contour, 0.01 * cv2.arcLength(contour, True), True)

        # drawContours() function
        cv2.drawContours(img, [contour], 0, (0, 0, 255), 5)

        # Finding the center of the shape
        M = cv2.moments(contour)
        if M['m00'] != 0.0:
            x = int(M['m10'] / M['m00'])
            y = int(M['m01'] / M['m00'])

            # Putting shape name at the center of each shape
            if len(approx) == 3:
                cv2.putText(img, 'Triangle', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
            elif len(approx) == 4:
                cv2.putText(img, 'Quadrilateral', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
            elif len(approx) == 5:
                cv2.putText(img, 'Pentagon', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
            elif len(approx) == 6:
                cv2.putText(img, 'Hexagon', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
            else:
                cv2.putText(img, 'Circle', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

    # Displaying the image using cv2_imshow
    cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=966x1128>
